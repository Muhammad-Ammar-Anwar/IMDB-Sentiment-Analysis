# %%
import numpy as np
import pandas as pd
from tensorflow.keras.datasets import imdb
from tensorflow.keras.preprocessing import sequence
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Embedding,SimpleRNN

# %%
max_features=10000
(x_train,y_train),(x_test,y_test)=imdb.load_data(num_words=max_features)

print(f'Training data shape: {x_train.shape}, Traning label shape: {y_train.shape}')
print(f'Testing data shape: {x_test.shape}, Testing label shape: {y_test.shape}')
# Out:
# Training data shape: (25000,), Traning label shape: (25000,)
# Testing data shape: (25000,), Testing label shape: (25000,)

# %%
sample_review=x_train[0]

sample_label=y_train[0]

print(f"Sample review as integers: {sample_review}")
print(f"Sample label: {sample_label}")
# Out:
# Sample review as integers: [1, 14, 22, 16, 43, 530, 973, 1622, 1385, 65, 458, 4468, 66, 3941, 4, 173, 36, 256, 5, 25, 100, 43, 838, 112, 50, 670, 2, 9, 35, 480, 284, 5, 150, 4, 172, 112, 167, 2, 336, 385, 39, 4, 172, 4536, 1111, 17, 546, 38, 13, 447, 4, 192, 50, 16, 6, 147, 2025, 19, 14, 22, 4, 1920, 4613, 469, 4, 22, 71, 87, 12, 16, 43, 530, 38, 76, 15, 13, 1247, 4, 22, 17, 515, 17, 12, 16, 626, 18, 2, 5, 62, 386, 12, 8, 316, 8, 106, 5, 4, 2223, 5244, 16, 480, 66, 3785, 33, 4, 130, 12, 16, 38, 619, 5, 25, 124, 51, 36, 135, 48, 25, 1415, 33, 6, 22, 12, 215, 28, 77, 52, 5, 14, 407, 16, 82, 2, 8, 4, 107, 117, 5952, 15, 256, 4, 2, 7, 3766, 5, 723, 36, 71, 43, 530, 476, 26, 400, 317, 46, 7, 4, 2, 1029, 13, 104, 88, 4, 381, 15, 297, 98, 32, 2071, 56, 26, 141, 6, 194, 7486, 18, 4, 226, 22, 21, 134, 476, 26, 480, 5, 144, 30, 5535, 18, 51, 36, 28, 224, 92, 25, 104, 4, 226, 65, 16, 38, 1334, 88, 12, 16, 283, 5, 16, 4472, 113, 103, 32, 15, 16, 5345, 19, 178, 32]
# Sample label: 1

# %%
word_index=imdb.get_word_index()
reverse_word_index={value: key for key,value in word_index.items()}
reverse_word_index
# Out:
# ...
# 1641221/1641221 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
# {34701: 'fawn',
#  52006: 'tsukino',
#  52007: 'nunnery',
#  16816: 'sonja',
#  63951: 'vani',
#  1408: 'woods',
#  16115: 'spiders',
#  2345: 'hanging',
#  2289: 'woody',
#  52008: 'trawling',
#  52009: "hold's",
#  11307: 'comically',
#  40830: 'localized',
#  30568: 'disobeying',
#  52010: "'royale",
#  40831: "harpo's",
#  52011: 'canet',
#  19313: 'aileen',
#  52012: 'acurately',
#  52013: "diplomat's",
#  25242: 'rickman',
#  6746: 'arranged',
#  52014: 'rumbustious',
#  52015: 'familiarness',
#  52016: "spider'",
#  68804: 'hahahah',
#  52017: "wood'",
#  40833: 'transvestism',
#  34702: "hangin'",
#  2338: 'bringing',
#  40834: 'seamier',
#  34703: 'wooded',
#  52018: 'bravora',
#  16817: 'grueling',
#  1636: 'wooden',
#  16818: 'wednesday',
#  52019: "'prix",
#  34704: 'altagracia',
#  52020: 'circuitry',
#  11585: 'crotch',
#  57766: 'busybody',
#  52021: "tart'n'tangy",
#  14129: 'burgade',
#  52023: 'thrace',
# ...

# %%
decoded_review=' '.join([reverse_word_index.get(i-3,'?') for i in sample_review])

# %%
from tensorflow.keras.preprocessing import sequence

max_len=500

x_train=sequence.pad_sequences(x_train,maxlen=max_len)
x_test=sequence.pad_sequences(x_test,maxlen=max_len)
x_train
# Out:
# array([[   0,    0,    0, ...,   19,  178,   32],
#        [   0,    0,    0, ...,   16,  145,   95],
#        [   0,    0,    0, ...,    7,  129,  113],
#        ...,
#        [   0,    0,    0, ...,    4, 3586,    2],
#        [   0,    0,    0, ...,   12,    9,   23],
#        [   0,    0,    0, ...,  204,  131,    9]], dtype=int32)

# %%
model=Sequential()
model.add(Embedding(max_features,128,input_length=max_len))
model.add(SimpleRNN(128,activation='relu'))
model.add(Dense(1,activation='sigmoid'))
model.build(input_shape=(None, max_len))
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(

# %%
from tensorflow.keras.callbacks import EarlyStopping
earlystopping=EarlyStopping(monitor='val_loss',patience=5,restore_best_weights=True)

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ embedding_1 (Embedding)              │ (None, 500, 128)            │       1,280,000 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ simple_rnn_2 (SimpleRNN)             │ (None, 128)                 │          32,896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 1)                   │             129 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 1,313,025 (5.01 MB)
#  Trainable params: 1,313,025 (5.01 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.fit(x_train,y_train,epochs=10,callbacks=[earlystopping],batch_size=32,validation_split=0.2)
# Out:
# Epoch 1/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 162s 255ms/step - accuracy: 0.5815 - loss: 174.0508 - val_accuracy: 0.6540 - val_loss: 0.6267
# Epoch 2/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 210s 268ms/step - accuracy: 0.7234 - loss: 0.5597 - val_accuracy: 0.7706 - val_loss: 0.4698
# Epoch 3/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 179s 231ms/step - accuracy: 0.8456 - loss: 0.3609 - val_accuracy: 0.8042 - val_loss: 0.4294
# Epoch 4/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 148s 236ms/step - accuracy: 0.8978 - loss: 0.2617 - val_accuracy: 0.8148 - val_loss: 0.4244
# Epoch 5/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 148s 238ms/step - accuracy: 0.8450 - loss: 0.3362 - val_accuracy: 0.7722 - val_loss: 0.5123
# Epoch 6/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 202s 238ms/step - accuracy: 0.8972 - loss: 0.2613 - val_accuracy: 0.8026 - val_loss: 0.4914
# Epoch 7/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 202s 238ms/step - accuracy: 0.9384 - loss: 0.1644 - val_accuracy: 0.8250 - val_loss: 0.4880
# Epoch 8/10
# ...

# %%
model.get_weights()
# Out:
# [array([[-0.3620219 ,  0.38658196, -0.32119298, ..., -0.3197962 ,
#           0.40775046,  0.3988297 ],
#         [ 0.00097619,  0.03486028, -0.02158411, ..., -0.06991178,
#           0.06203108,  0.0874404 ],
#         [-0.04077492,  0.08870377, -0.09745963, ..., -0.11787301,
#           0.02454398,  0.04139776],
#         ...,
#         [ 0.02068792, -0.1380234 ,  0.0940872 , ...,  0.02339218,
#           0.03160556, -0.0935185 ],
#         [ 0.02567865, -0.00535222, -0.0060779 , ...,  0.07013045,
#           0.0429679 , -0.02859521],
#         [ 0.03685578, -0.04186608, -0.03780416, ..., -0.01771484,
#           0.07397033, -0.07010117]], dtype=float32),
#  array([[ 0.08554033, -0.03698738,  0.03116455, ..., -0.01059975,
#           0.08839466, -0.04640511],
#         [ 0.15553471,  0.16616848,  0.08650938, ..., -0.04573641,
#          -0.10934723,  0.08848348],
#         [-0.12458859,  0.1206452 , -0.01051754, ...,  0.10836681,
#           0.09563985, -0.0829553 ],
# ...

# %%
def decoded_review(encoded_review):
  return ' '.join([reverse_word_index.get(i-3,'?') for i in encoded_review])

def preprocessing_test(text):
  words=text.lower().split()
  encoded_review = [word_index.get(word,2) +3 for word in words]
  padded_review= sequence.pad_sequences([encoded_review], maxlen=500)
  return padded_review

# %%
def predict_sentiment(review):
  preprocess_input=preprocessing_test(review)

  prediction= model.predict(preprocess_input)

  sentiment= 'Positive' if prediction[0][0] > 0.5 else 'Negative'

  return sentiment, prediction[0][0]

# %%
example_review="This movie was an absolute masterpiece! The storytelling was captivating, the acting was phenomenal, and the visuals were stunning."

# %%
sentiment , score = predict_sentiment(example_review)

print(f'Review: {example_review}')
print(f'Sentiment: {sentiment}')
print(f'Prediction score: {score}')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# Review: This movie was an absolute masterpiece! The storytelling was captivating, the acting was phenomenal, and the visuals were stunning.
# Sentiment: Positive
# Prediction score: 0.9130788445472717

# %%
example_review2="This movie was a complete waste of time. The plot was predictable and boring, the acting was wooden and unconvincing, and the special effects were laughably bad. I spent most of the movie checking my watch and wishing it would end. Avoid this film at all costs."

# %%
sentiment , score = predict_sentiment(example_review2)

print(f'Review: {example_review2}')
print(f'Sentiment: {sentiment}')
print(f'Prediction score: {score}')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# Review: This movie was a complete waste of time. The plot was predictable and boring, the acting was wooden and unconvincing, and the special effects were laughably bad. I spent most of the movie checking my watch and wishing it would end. Avoid this film at all costs.
# Sentiment: Negative
# Prediction score: 0.018978821113705635
